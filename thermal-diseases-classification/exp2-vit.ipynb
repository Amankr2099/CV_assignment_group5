# %%
import os
import cv2
import numpy as np
import random
import albumentations as A
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.optimizers import Adam
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, Conv2DTranspose, 
                                     concatenate, Dense, Flatten, Dropout, BatchNormalization, 
                                     GlobalAveragePooling2D)
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import precision_recall_curve

print("Starting model preparation...")

# -------------------------------
# CUSTOM VISION TRANSFORMER (ViT)
# -------------------------------
from tensorflow.keras import layers, models

class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size
        
    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID"
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )
        
    def call(self, patches):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patches) + self.position_embedding(positions)
        return encoded

def transformer_block(inputs, num_heads, projection_dim, dropout_rate):
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    attention_output = layers.MultiHeadAttention(
        num_heads=num_heads, key_dim=projection_dim, dropout=dropout_rate
    )(x, x)
    x = layers.Add()([attention_output, inputs])
    y = layers.LayerNormalization(epsilon=1e-6)(x)
    y = layers.Dense(projection_dim * 2, activation=tf.nn.gelu)(y)
    y = layers.Dense(projection_dim)(y)
    return layers.Add()([x, y])

def vit_classifier(input_shape=(224, 224, 3), num_classes=6,
                   patch_size=16, num_layers=8, num_heads=4, projection_dim=64,
                   dropout_rate=0.1):
    print("\nBuilding ViT Classifier...")
    inputs = layers.Input(shape=input_shape)
    
    patches = Patches(patch_size)(inputs)
    num_patches = (input_shape[0] // patch_size) * (input_shape[1] // patch_size)
    
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)
    
    for i in range(num_layers):
        print(f"Adding transformer block {i+1}/{num_layers}")
        encoded_patches = transformer_block(encoded_patches, num_heads, projection_dim, dropout_rate)
    
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.GlobalAveragePooling1D()(representation)
    representation = layers.Dropout(dropout_rate)(representation)
    
    outputs = layers.Dense(num_classes, activation='softmax')(representation)
    
    model = models.Model(inputs=inputs, outputs=outputs)
    return model

# ------------------------------------
# DATA PREPARATION & AUGMENTATION SETUP
# ------------------------------------
print("\nSetting up data preparation...")

dataset_path = "/kaggle/input/thermal-images-diseased-healthy-leaves-paddy/thermal images UL"
output_path = "/kaggle/working/expanded_dataset"
final_dataset_path = "/kaggle/working/final_processed_dataset"

valid_labels = {"BLB", "Blast", "healthy", "hispa", "leaf folder", "leaf spot"}

os.makedirs(output_path, exist_ok=True)
os.makedirs(final_dataset_path, exist_ok=True)

print("\nConfiguring augmentations...")
augmentations = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.Rotate(limit=45, p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.GaussianBlur(p=0.3),
    A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=0.5),
    A.RandomResizedCrop(height=200, width=200, scale=(0.7, 1.0), p=0.5),
    A.GridDistortion(p=0.3),
    A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=30, p=0.5)
])

print("\nExpanding dataset...")
for label in os.listdir(dataset_path):
    if label not in valid_labels:
        continue
    print(f"Processing {label} images...")
    label_path = os.path.join(dataset_path, label)
    save_path = os.path.join(output_path, label)
    os.makedirs(save_path, exist_ok=True)
    
    images = [os.path.join(label_path, img) for img in os.listdir(label_path)]
    
    while len(images) < 220:
        img_path = random.choice(images)
        img = cv2.imread(img_path)
        if img is None:
            continue
        augmented = augmentations(image=img)["image"]
        cv2.imwrite(os.path.join(save_path, f"aug_{len(images)}.jpg"), augmented)
        images.append(img_path)

print("\nPreparing dataset splits...")
all_images, all_labels = [], []
label_map = {label: idx for idx, label in enumerate(valid_labels)}

for label in valid_labels:
    label_path = os.path.join(output_path, label)
    for img_file in os.listdir(label_path):
        all_images.append(os.path.join(label_path, img_file))
        all_labels.append(label_map[label])

train_imgs, temp_imgs, train_labels, temp_labels = train_test_split(
    all_images, all_labels, test_size=0.4, stratify=all_labels, random_state=42
)
val_imgs, test_imgs, val_labels, test_labels = train_test_split(
    temp_imgs, temp_labels, test_size=0.5, stratify=temp_labels, random_state=42
)

print(f"\nDataset split sizes:")
print(f"Training: {len(train_imgs)} images")
print(f"Validation: {len(val_imgs)} images")
print(f"Testing: {len(test_imgs)} images")

class_weights = compute_class_weight("balanced", classes=np.unique(all_labels), y=all_labels)
class_weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

train_labels = list(map(str, train_labels))
val_labels = list(map(str, val_labels))
test_labels = list(map(str, test_labels))

print("\nSetting up data generators...")
datagen = ImageDataGenerator(rescale=1.0/255)
train_gen = datagen.flow_from_dataframe(
    pd.DataFrame({"filename": train_imgs, "class": train_labels}), 
    x_col="filename", 
    y_col="class", 
    target_size=(224, 224), 
    batch_size=32, 
    class_mode="sparse"
)
val_gen = datagen.flow_from_dataframe(
    pd.DataFrame({"filename": val_imgs, "class": val_labels}), 
    x_col="filename", 
    y_col="class", 
    target_size=(224, 224), 
    batch_size=32, 
    class_mode="sparse"
)
test_gen = datagen.flow_from_dataframe(
    pd.DataFrame({"filename": test_imgs, "class": test_labels}), 
    x_col="filename", 
    y_col="class", 
    target_size=(224, 224), 
    batch_size=32, 
    class_mode="sparse", 
    shuffle=False
)

# --------------------------
# CREATE & COMPILE THE MODEL
# --------------------------
print("\nCreating and compiling the model...")
model = vit_classifier(input_shape=(224, 224, 3), num_classes=6,
                       patch_size=16, num_layers=8, num_heads=4, projection_dim=64,
                       dropout_rate=0.1)

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# --------------------------
# TRAINING THE MODEL
# --------------------------
print("\nSetting up training callbacks...")
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)

print("\nStarting model training...")
history = model.fit(
    train_gen, 
    validation_data=val_gen, 
    epochs=30,  # Increased to 30 epochs
    class_weight=class_weight_dict, 
    callbacks=[lr_scheduler, early_stopping],
    verbose=1  # Show detailed progress
)

print("\nEvaluating model on test data...")
test_loss, test_accuracy = model.evaluate(test_gen)
print(f"Final Test Accuracy: {test_accuracy:.4f}")

# --------------------------
# PLOTTING RESULTS
# --------------------------
print("\nGenerating performance plots...")
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

print("\nGenerating precision-recall curves...")
num_classes = len(valid_labels)
y_true = tf.keras.utils.to_categorical(test_gen.classes, num_classes)
y_probs = model.predict(test_gen)

plt.figure(figsize=(10, 6))
for i in range(num_classes):
    precision, recall, _ = precision_recall_curve(y_true[:, i], y_probs[:, i])
    plt.plot(recall, precision, marker='.', label=f'Class {i}')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve for Each Class')
plt.legend()
plt.show()

print("\nTraining pipeline completed!")
# Out:
# Starting model preparation...
#
# Setting up data preparation...
#
# Configuring augmentations...
#
# Expanding dataset...
# Processing hispa images...
# <ipython-input-2-b22c5c619161>:118: UserWarning: Argument 'alpha_affine' is not valid and will be ignored.
#   A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=0.5),
# Processing leaf folder images...
# Processing BLB images...
# Processing Blast images...
# Processing healthy images...
# Processing leaf spot images...
#
# Preparing dataset splits...
#
# Dataset split sizes:
# Training: 410 images
# Validation: 137 images
# Testing: 137 images
#
# Setting up data generators...
# Found 410 validated image filenames belonging to 5 classes.
# Found 137 validated image filenames belonging to 5 classes.
# Found 137 validated image filenames belonging to 5 classes.
#
# Creating and compiling the model...
#
# Building ViT Classifier...
# Adding transformer block 1/8
# Adding transformer block 2/8
# Adding transformer block 3/8
# Adding transformer block 4/8
# Adding transformer block 5/8
# Adding transformer block 6/8
# Adding transformer block 7/8
# Adding transformer block 8/8
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ patches_1 (Patches)       │ (None, None, 768)      │              0 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ patch_encoder_1           │ (None, 196, 64)        │         61,760 │ patches_1[0][0]        │
# │ (PatchEncoder)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_17    │ (None, 196, 64)        │            128 │ patch_encoder_1[0][0]  │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_8    │ (None, 196, 64)        │         66,368 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_16 (Add)              │ (None, 196, 64)        │              0 │ multi_head_attention_… │
# │                           │                        │                │ patch_encoder_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_18    │ (None, 196, 64)        │            128 │ add_16[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_19 (Dense)          │ (None, 196, 128)       │          8,320 │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_20 (Dense)          │ (None, 196, 64)        │          8,256 │ dense_19[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_17 (Add)              │ (None, 196, 64)        │              0 │ add_16[0][0],          │
# │                           │                        │                │ dense_20[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_19    │ (None, 196, 64)        │            128 │ add_17[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_9    │ (None, 196, 64)        │         66,368 │ layer_normalization_1… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_18 (Add)              │ (None, 196, 64)        │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_17[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_20    │ (None, 196, 64)        │            128 │ add_18[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_21 (Dense)          │ (None, 196, 128)       │          8,320 │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_22 (Dense)          │ (None, 196, 64)        │          8,256 │ dense_21[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_19 (Add)              │ (None, 196, 64)        │              0 │ add_18[0][0],          │
# │                           │                        │                │ dense_22[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_21    │ (None, 196, 64)        │            128 │ add_19[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_10   │ (None, 196, 64)        │         66,368 │ layer_normalization_2… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_20 (Add)              │ (None, 196, 64)        │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_19[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_22    │ (None, 196, 64)        │            128 │ add_20[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_23 (Dense)          │ (None, 196, 128)       │          8,320 │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_24 (Dense)          │ (None, 196, 64)        │          8,256 │ dense_23[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_21 (Add)              │ (None, 196, 64)        │              0 │ add_20[0][0],          │
# │                           │                        │                │ dense_24[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_23    │ (None, 196, 64)        │            128 │ add_21[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_11   │ (None, 196, 64)        │         66,368 │ layer_normalization_2… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_22 (Add)              │ (None, 196, 64)        │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_21[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_24    │ (None, 196, 64)        │            128 │ add_22[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_25 (Dense)          │ (None, 196, 128)       │          8,320 │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_26 (Dense)          │ (None, 196, 64)        │          8,256 │ dense_25[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_23 (Add)              │ (None, 196, 64)        │              0 │ add_22[0][0],          │
# │                           │                        │                │ dense_26[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_25    │ (None, 196, 64)        │            128 │ add_23[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_12   │ (None, 196, 64)        │         66,368 │ layer_normalization_2… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_24 (Add)              │ (None, 196, 64)        │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_23[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_26    │ (None, 196, 64)        │            128 │ add_24[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_27 (Dense)          │ (None, 196, 128)       │          8,320 │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_28 (Dense)          │ (None, 196, 64)        │          8,256 │ dense_27[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_25 (Add)              │ (None, 196, 64)        │              0 │ add_24[0][0],          │
# │                           │                        │                │ dense_28[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_27    │ (None, 196, 64)        │            128 │ add_25[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_13   │ (None, 196, 64)        │         66,368 │ layer_normalization_2… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_26 (Add)              │ (None, 196, 64)        │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_25[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_28    │ (None, 196, 64)        │            128 │ add_26[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_29 (Dense)          │ (None, 196, 128)       │          8,320 │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_30 (Dense)          │ (None, 196, 64)        │          8,256 │ dense_29[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_27 (Add)              │ (None, 196, 64)        │              0 │ add_26[0][0],          │
# │                           │                        │                │ dense_30[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_29    │ (None, 196, 64)        │            128 │ add_27[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_14   │ (None, 196, 64)        │         66,368 │ layer_normalization_2… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_28 (Add)              │ (None, 196, 64)        │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_27[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_30    │ (None, 196, 64)        │            128 │ add_28[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_31 (Dense)          │ (None, 196, 128)       │          8,320 │ layer_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_32 (Dense)          │ (None, 196, 64)        │          8,256 │ dense_31[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_29 (Add)              │ (None, 196, 64)        │              0 │ add_28[0][0],          │
# │                           │                        │                │ dense_32[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_31    │ (None, 196, 64)        │            128 │ add_29[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_15   │ (None, 196, 64)        │         66,368 │ layer_normalization_3… │
# │ (MultiHeadAttention)      │                        │                │ layer_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_30 (Add)              │ (None, 196, 64)        │              0 │ multi_head_attention_… │
# │                           │                        │                │ add_29[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_32    │ (None, 196, 64)        │            128 │ add_30[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_33 (Dense)          │ (None, 196, 128)       │          8,320 │ layer_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_34 (Dense)          │ (None, 196, 64)        │          8,256 │ dense_33[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_31 (Add)              │ (None, 196, 64)        │              0 │ add_30[0][0],          │
# │                           │                        │                │ dense_34[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_33    │ (None, 196, 64)        │            128 │ add_31[0][0]           │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d… │ (None, 64)             │              0 │ layer_normalization_3… │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_17 (Dropout)      │ (None, 64)             │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_35 (Dense)          │ (None, 6)              │            390 │ dropout_17[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 727,878 (2.78 MB)
#  Trainable params: 727,878 (2.78 MB)
#  Non-trainable params: 0 (0.00 B)
# Setting up training callbacks...
#
# Starting model training...
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.2557 - loss: 1.7948 - val_accuracy: 0.3431 - val_loss: 1.4498 - learning_rate: 1.0000e-04
# Epoch 2/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.3086 - loss: 1.5139 - val_accuracy: 0.4380 - val_loss: 1.3298 - learning_rate: 1.0000e-04
# Epoch 3/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.3738 - loss: 1.5130 - val_accuracy: 0.4380 - val_loss: 1.2877 - learning_rate: 1.0000e-04
# Epoch 4/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.4081 - loss: 1.3851 - val_accuracy: 0.4891 - val_loss: 1.2954 - learning_rate: 1.0000e-04
# Epoch 5/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.4222 - loss: 1.3695 - val_accuracy: 0.5109 - val_loss: 1.2290 - learning_rate: 1.0000e-04
# Epoch 6/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.4734 - loss: 1.3039 - val_accuracy: 0.4964 - val_loss: 1.2761 - learning_rate: 1.0000e-04
# Epoch 7/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.4536 - loss: 1.3682 - val_accuracy: 0.5036 - val_loss: 1.1690 - learning_rate: 1.0000e-04
# Epoch 8/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.5278 - loss: 1.2114 - val_accuracy: 0.5328 - val_loss: 1.1941 - learning_rate: 1.0000e-04
# Epoch 9/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.5325 - loss: 1.2536 - val_accuracy: 0.5401 - val_loss: 1.1810 - learning_rate: 1.0000e-04
# Epoch 10/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.5677 - loss: 1.2003 - val_accuracy: 0.5255 - val_loss: 1.1323 - learning_rate: 1.0000e-04
# Epoch 11/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.4881 - loss: 1.2553 - val_accuracy: 0.5109 - val_loss: 1.1605 - learning_rate: 1.0000e-04
# Epoch 12/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.5263 - loss: 1.2220 - val_accuracy: 0.5401 - val_loss: 1.1690 - learning_rate: 1.0000e-04
# Epoch 13/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.6031 - loss: 1.1038 - val_accuracy: 0.5547 - val_loss: 1.1074 - learning_rate: 1.0000e-04
# Epoch 14/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.6025 - loss: 1.0892 - val_accuracy: 0.5839 - val_loss: 1.1246 - learning_rate: 1.0000e-04
# Epoch 15/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.5520 - loss: 1.1403 - val_accuracy: 0.5109 - val_loss: 1.1784 - learning_rate: 1.0000e-04
# Epoch 16/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.5628 - loss: 1.1267 - val_accuracy: 0.5766 - val_loss: 1.1150 - learning_rate: 1.0000e-04
# Epoch 17/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.6113 - loss: 1.0878 - val_accuracy: 0.5328 - val_loss: 1.1271 - learning_rate: 5.0000e-05
# Epoch 18/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.6005 - loss: 1.0903 - val_accuracy: 0.5693 - val_loss: 1.1140 - learning_rate: 5.0000e-05
# Epoch 19/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.6268 - loss: 1.0311 - val_accuracy: 0.5839 - val_loss: 1.0927 - learning_rate: 5.0000e-05
# Epoch 20/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.6381 - loss: 1.0568 - val_accuracy: 0.5620 - val_loss: 1.0991 - learning_rate: 5.0000e-05
# Epoch 21/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.6437 - loss: 1.0634 - val_accuracy: 0.5693 - val_loss: 1.1143 - learning_rate: 5.0000e-05
# Epoch 22/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.6009 - loss: 1.1034 - val_accuracy: 0.5547 - val_loss: 1.1231 - learning_rate: 5.0000e-05
# Epoch 23/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.6563 - loss: 0.9967 - val_accuracy: 0.5985 - val_loss: 1.1098 - learning_rate: 2.5000e-05
# Epoch 24/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.6170 - loss: 1.0098 - val_accuracy: 0.5693 - val_loss: 1.0989 - learning_rate: 2.5000e-05
# Epoch 25/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.6064 - loss: 1.0745 - val_accuracy: 0.5620 - val_loss: 1.0982 - learning_rate: 2.5000e-05
# Epoch 26/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.6078 - loss: 1.0506 - val_accuracy: 0.5766 - val_loss: 1.1044 - learning_rate: 1.2500e-05
#
# Evaluating model on test data...
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6280 - loss: 0.9718
# Final Test Accuracy: 0.6131
#
# Generating performance plots...
# Generating precision-recall curves...
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 846ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py:891: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# Training pipeline completed!
